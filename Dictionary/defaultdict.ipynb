# %%
from collections import defaultdict
import collections

# %%
# collections is a module means it is collections.py file
# collections.py file contains classes and functions
type(collections)
# Out:
# module

# %%
# defaultdict is a dictionary subclass that calls a factory function to supply missing values
# defaultdict is a class in collections module
type(defaultdict)
# Out:
# type

# %%
students = {101: 'Alice', 102: 'Bob', 103: 'Charlie'}
print(students[101])  # Output: Alice
# Out:
# Alice

# %%
students
# Out:
# {101: 'Alice', 102: 'Bob', 103: 'Charlie'}

# %%
studentInfo = [['ravi', 25], ['sita', 30], ['gita', 28]]
studentInfo
# Out:
# [['ravi', 25], ['sita', 30], ['gita', 28]]

# %%
for i in studentInfo:
    print(i)
# Out:
# ['ravi', 25]
# ['sita', 30]
# ['gita', 28]

# %%
for i in studentInfo:
    print(i[0])  # Print the name
# Out:
# ravi
# sita
# gita

# %%
for i in studentInfo:
    print(i[1])  # Print the age
# Out:
# 25
# 30
# 28

# %%
d1={'ravi': [25,11], 'sita': [30,22], 'gita': [28,33]}
d1
# Out:
# {'ravi': [25, 11], 'sita': [30, 22], 'gita': [28, 33]}

# %%
do1=defaultdict(list)
do1
# Out:
# defaultdict(list, {})

# %%
# defaultdict(list) means that if we try to access a key that does not exist in the dictionary, it will return an empty list instead of raising a KeyError.
# The list is the default factory function that is called to create a default value for the missing key.
do1.default_factory()
# Out:
# []

# %%
do1['ravi'].append(25)
do1
# Out:
# defaultdict(list, {'ravi': [25]})

# %%
do1['sita'].append(30)
do1
# Out:
# defaultdict(list, {'ravi': [25], 'sita': [30]})

# %%
do1['gita'].append(28)
do1
# Out:
# defaultdict(list, {'ravi': [25], 'sita': [30], 'gita': [28]})

# %%
do1['giri'].append(25)
do1
# Out:
# defaultdict(list, {'ravi': [25], 'sita': [30], 'gita': [28], 'giri': [25]})

# %%
do1['hari'].append(22)
do1
# Out:
# defaultdict(list,
#             {'ravi': [25],
#              'sita': [30],
#              'gita': [28],
#              'giri': [25],
#              'hari': [22]})

# %%
v1="mississippi"
for i in v1:
    print(i)
# Out:
# m
# i
# s
# s
# i
# s
# s
# i
# p
# p
# i

# %%
v1.count('i')
# Out:
# 4

# %%
v1.count('s')
# Out:
# 4

# %%
do3=defaultdict(int)
do3
# Out:
# defaultdict(int, {})

# %%
do3.default_factory()
# Out:
# 0

# %%
for i in v1:
    do3[i]=do3[i]+1
do3
# Out:
# defaultdict(int, {'m': 1, 'i': 4, 's': 4, 'p': 2})

# %%
for i in v1:
    do3[i]=1+do3[i]
do3
# Out:
# defaultdict(int, {'m': 2, 'i': 8, 's': 8, 'p': 4})

# %%
do4 = defaultdict(int)
do4
# Out:
# defaultdict(int, {})

# %%
name = input("Enter emp name: ")
do4[name] = do4[name] + 1
do4
# Out:
# defaultdict(int, {'ravi': 2, 'sita': 1, 'ramu': 1})
