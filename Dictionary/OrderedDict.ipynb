# %%
import collections as cl
from collections import defaultdict

# %%
d1 = {4:400,2:200,3:300,1:100,5:500,6:600}
d1
# Out:
# {4: 400, 2: 200, 3: 300, 1: 100, 5: 500, 6: 600}

# %%
od1=cl.OrderedDict(d1)
od1
# Out:
# OrderedDict([(4, 400), (2, 200), (3, 300), (1, 100), (5, 500), (6, 600)])

# %%
od1.move_to_end(2)
od1
# Out:
# OrderedDict([(1, 100), (4, 400), (3, 300), (6, 600), (5, 500), (2, 200)])

# %%
od1.move_to_end(3)
od1
# Out:
# OrderedDict([(1, 100), (4, 400), (6, 600), (5, 500), (2, 200), (3, 300)])

# %%
od1.move_to_end(4)
od1
# Out:
# OrderedDict([(1, 100), (6, 600), (5, 500), (2, 200), (3, 300), (4, 400)])

# %%
od1.move_to_end(5)
od1
# Out:
# OrderedDict([(1, 100), (6, 600), (2, 200), (3, 300), (4, 400), (5, 500)])

# %%
od1.move_to_end(6)
od1
# Out:
# OrderedDict([(1, 100), (2, 200), (3, 300), (4, 400), (5, 500), (6, 600)])

# %%
od1.move_to_end(1,last=False)
od1.
# Out:
# OrderedDict([(1, 100), (2, 200), (3, 300), (4, 400), (5, 500), (6, 600)])

# %%
for i in od1.items():
    print(i)
# Out:
# (1, 100)
# (2, 200)
# (3, 300)
# (4, 400)
# (5, 500)
# (6, 600)

# %%
dir(cl.OrderedDict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'move_to_end',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']
